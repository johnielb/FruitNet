# %%
# ** COMP309 Project **
# Johniel Bocacao
# 300490028

###
# Step 0: Load data
###

import os
import torch
from PIL import Image
from torchvision.transforms import ToTensor

base_dir = "traindata"
train_list = []
y_train = []
throwaway = []
for class_type in sorted(os.listdir(base_dir)):
    if class_type == ".DS_Store": continue
    subdir = os.path.join(base_dir, class_type)
    for filename in sorted(os.listdir(subdir)):
        if filename == ".DS_Store": continue
        filepath = os.path.join(subdir, filename)
        image = ToTensor()(Image.open(filepath)).unsqueeze(0)
        if list(image.size())[1:] == [3, 300, 300]:
            train_list.append(image)
            y_train.append(class_type)
        else:
            print(filepath, "is not size 300x300, image is:", image.size())
            throwaway.append(image)

X_train = torch.Tensor((len(train_list), 3, 300, 300))
torch.cat(train_list, out=X_train)
# Out:
# traindata/cherry/cherry_0113.jpg is not size 300x300, image is: torch.Size([1, 3, 230, 219])
# traindata/cherry/cherry_0226.jpg is not size 300x300, image is: torch.Size([1, 3, 169, 299])
# traindata/cherry/cherry_0257.jpg is not size 300x300, image is: torch.Size([1, 3, 229, 220])
# traindata/cherry/cherry_0366.jpg is not size 300x300, image is: torch.Size([1, 3, 193, 261])
# traindata/cherry/cherry_0519.jpg is not size 300x300, image is: torch.Size([1, 3, 225, 225])
# traindata/cherry/cherry_0549.jpg is not size 300x300, image is: torch.Size([1, 3, 251, 201])
# traindata/cherry/cherry_0745.jpg is not size 300x300, image is: torch.Size([1, 3, 225, 225])
# traindata/cherry/cherry_0843.jpg is not size 300x300, image is: torch.Size([1, 3, 225, 225])
# traindata/cherry/cherry_0873.jpg is not size 300x300, image is: torch.Size([1, 3, 225, 225])
# traindata/cherry/cherry_1005.jpg is not size 300x300, image is: torch.Size([1, 3, 225, 225])
# traindata/cherry/cherry_1017.jpg is not size 300x300, image is: torch.Size([1, 3, 225, 225])
# traindata/cherry/cherry_1019.jpg is not size 300x300, image is: torch.Size([1, 3, 183, 275])
# traindata/cherry/cherry_1020.jpg is not size 300x300, image is: torch.Size([1, 3, 225, 225])
# traindata/cherry/cherry_1066.jpg is not size 300x300, image is: torch.Size([1, 3, 278, 181])
# traindata/cherry/cherry_1154.jpg is not size 300x300, image is: torch.Size([1, 3, 251, 201])
# traindata/cherry/cherry_1357.jpg is not size 300x300, image is: torch.Size([1, 3, 225, 225])
# traindata/cherry/cherry_1358.jpg is not size 300x300, image is: torch.Size([1, 3, 225, 225])
# traindata/cherry/cherry_1359.jpg is not size 300x300, image is: torch.Size([1, 3, 251, 201])
# traindata/cherry/cherry_1842.jpg is not size 300x300, image is: torch.Size([1, 3, 234, 215])
# traindata/cherry/cherry_2264.jpg is not size 300x300, image is: torch.Size([1, 3, 229, 220])
# traindata/strawberry/strawberry_0082.jpg is not size 300x300, image is: torch.Size([1, 3, 279, 181])
# traindata/strawberry/strawberry_0083.jpg is not size 300x300, image is: torch.Size([1, 3, 225, 225])
# traindata/tomato/tomato_0433.jpg is not size 300x300, image is: torch.Size([1, 3, 199, 254])
# traindata/tomato/tomato_0500.jpg is not size 300x300, image is: torch.Size([1, 3, 283, 178])
# traindata/tomato/tomato_0516.jpg is not size 300x300, image is: torch.Size([1, 3, 225, 225])
# traindata/tomato/tomato_0641.jpg is not size 300x300, image is: torch.Size([1, 3, 250, 202])
# traindata/tomato/tomato_1188.jpg is not size 300x300, image is: torch.Size([1, 3, 225, 225])
# traindata/tomato/tomato_1568.jpg is not size 300x300, image is: torch.Size([1, 3, 232, 217])
# traindata/tomato/tomato_1957.jpg is not size 300x300, image is: torch.Size([1, 3, 193, 261])
# traindata/tomato/tomato_1958.jpg is not size 300x300, image is: torch.Size([1, 3, 203, 249])
# traindata/tomato/tomato_1959.jpg is not size 300x300, image is: torch.Size([1, 3, 225, 225])
# tensor([[[[0.0353, 0.0196, 0.0118,  ..., 0.3647, 0.3647, 0.3608],
#           [0.0275, 0.0196, 0.0118,  ..., 0.3647, 0.3686, 0.3647],
#           [0.0196, 0.0196, 0.0157,  ..., 0.3686, 0.3686, 0.3647],
#           ...,
#           [0.2745, 0.2863, 0.2980,  ..., 0.5882, 0.5843, 0.5843],
#           [0.2980, 0.3059, 0.3176,  ..., 0.5725, 0.5686, 0.5686],
#           [0.3098, 0.3216, 0.3294,  ..., 0.5647, 0.5608, 0.5569]],
#
#          [[0.0039, 0.0000, 0.0000,  ..., 0.3882, 0.3804, 0.3765],
#           [0.0000, 0.0000, 0.0000,  ..., 0.3882, 0.3843, 0.3804],
#           [0.0000, 0.0000, 0.0078,  ..., 0.3922, 0.3843, 0.3804],
#           ...,
#           [0.2902, 0.3020, 0.3137,  ..., 0.5608, 0.5529, 0.5529],
#           [0.3137, 0.3216, 0.3333,  ..., 0.5451, 0.5412, 0.5373],
#           [0.3255, 0.3373, 0.3451,  ..., 0.5373, 0.5333, 0.5294]],
#
#          [[0.0627, 0.0431, 0.0275,  ..., 0.2392, 0.2353, 0.2314],
#           [0.0549, 0.0431, 0.0275,  ..., 0.2392, 0.2392, 0.2353],
#           [0.0431, 0.0353, 0.0275,  ..., 0.2431, 0.2392, 0.2353],
#           ...,
#           [0.3255, 0.3373, 0.3490,  ..., 0.5922, 0.5961, 0.5961],
#           [0.3490, 0.3569, 0.3686,  ..., 0.5765, 0.5725, 0.5804],
#           [0.3686, 0.3804, 0.3882,  ..., 0.5686, 0.5647, 0.5608]]],
#
#
#         [[[1.0000, 1.0000, 0.7647,  ..., 0.6078, 0.6118, 0.6157],
#           [1.0000, 0.8392, 0.5490,  ..., 0.6235, 0.6235, 0.6314],
#           [0.9098, 0.5647, 0.3490,  ..., 0.6471, 0.6471, 0.6510],
#           ...,
#           [0.9333, 0.6863, 0.4902,  ..., 0.1961, 0.2471, 0.3412],
#           [0.8078, 0.5843, 0.5098,  ..., 0.2000, 0.2667, 0.3647],
#           [0.7373, 0.5216, 0.5255,  ..., 0.2039, 0.2784, 0.3843]],
#
#          [[0.9333, 0.9686, 0.7020,  ..., 0.8706, 0.8745, 0.8863],
#           [0.9294, 0.7647, 0.5020,  ..., 0.8627, 0.8706, 0.8784],
#           [0.8471, 0.5176, 0.3216,  ..., 0.8549, 0.8627, 0.8706],
#           ...,
#           [0.8392, 0.6039, 0.4118,  ..., 0.2510, 0.3059, 0.4000],
#           [0.7137, 0.5020, 0.4314,  ..., 0.2549, 0.3216, 0.4196],
#           [0.6392, 0.4275, 0.4471,  ..., 0.2510, 0.3216, 0.4275]],
#
#          [[0.9255, 0.9725, 0.7412,  ..., 1.0000, 1.0000, 1.0000],
#           [0.9333, 0.7882, 0.5490,  ..., 1.0000, 1.0000, 1.0000],
#           [0.8863, 0.5647, 0.3922,  ..., 1.0000, 1.0000, 1.0000],
#           ...,
#           [0.8314, 0.6000, 0.4157,  ..., 0.1137, 0.1765, 0.2706],
#           [0.7059, 0.4902, 0.4275,  ..., 0.1176, 0.1922, 0.2902],
#           [0.6235, 0.4196, 0.4431,  ..., 0.1098, 0.1961, 0.3020]]],
#
#
#         [[[0.3098, 0.3529, 0.2941,  ..., 0.3176, 0.3216, 0.3255],
#           [0.3961, 0.4980, 0.4863,  ..., 0.2824, 0.2902, 0.2941],
#           [0.5804, 0.6667, 0.6863,  ..., 0.2941, 0.3020, 0.3059],
#           ...,
#           [0.1765, 0.1490, 0.1373,  ..., 0.3608, 0.3608, 0.3373],
#           [0.1804, 0.1569, 0.1451,  ..., 0.3529, 0.3490, 0.3294],
#           [0.1843, 0.1608, 0.1490,  ..., 0.5216, 0.5176, 0.4941]],
#
#          [[0.4196, 0.4627, 0.4039,  ..., 0.5373, 0.5451, 0.5412],
#           [0.4902, 0.6039, 0.5922,  ..., 0.5020, 0.5137, 0.5098],
#           [0.6706, 0.7569, 0.7765,  ..., 0.5137, 0.5255, 0.5216],
#           ...,
#           [0.1176, 0.0863, 0.0745,  ..., 0.3686, 0.3686, 0.3490],
#           [0.1294, 0.1059, 0.0941,  ..., 0.3608, 0.3569, 0.3412],
#           [0.1412, 0.1176, 0.1059,  ..., 0.5255, 0.5216, 0.5059]],
#
#          [[0.1882, 0.2314, 0.1725,  ..., 0.5255, 0.5216, 0.5216],
#           [0.2863, 0.3961, 0.3843,  ..., 0.4902, 0.4902, 0.4902],
#           [0.5059, 0.5922, 0.6039,  ..., 0.5020, 0.5020, 0.5020],
#           ...,
#           [0.1451, 0.1255, 0.1137,  ..., 0.2157, 0.2118, 0.1804],
#           [0.1647, 0.1412, 0.1294,  ..., 0.2039, 0.2000, 0.1725],
#           [0.1725, 0.1490, 0.1373,  ..., 0.3686, 0.3569, 0.3373]]],
#
#
#         ...,
#
#
#           ...,
#           [0.0235, 0.0235, 0.0235,  ..., 0.0353, 0.0353, 0.0353],
#           [0.0235, 0.0235, 0.0235,  ..., 0.0353, 0.0353, 0.0353],
#           [0.0235, 0.0235, 0.0235,  ..., 0.0353, 0.0353, 0.0353]]],
#
#
#         [[[0.5333, 0.5373, 0.5412,  ..., 0.5569, 0.5333, 0.5176],
#           [0.5647, 0.5686, 0.5725,  ..., 0.5686, 0.5451, 0.5294],
#           [0.5922, 0.5961, 0.6000,  ..., 0.5843, 0.5647, 0.5490],
#           ...,
#           [0.4314, 0.3961, 0.3725,  ..., 0.2431, 0.2353, 0.2275],
#           [0.4157, 0.3647, 0.3373,  ..., 0.2196, 0.2118, 0.2039],
#           [0.4275, 0.3765, 0.3490,  ..., 0.2353, 0.2314, 0.2196]],
#
#          [[0.5020, 0.5059, 0.5098,  ..., 0.4863, 0.4627, 0.4471],
#           [0.5333, 0.5373, 0.5412,  ..., 0.4980, 0.4745, 0.4588],
#           [0.5608, 0.5647, 0.5686,  ..., 0.5137, 0.4941, 0.4784],
#           ...,
#           [0.3569, 0.3216, 0.2980,  ..., 0.1647, 0.1647, 0.1569],
#           [0.3412, 0.2902, 0.2627,  ..., 0.1490, 0.1412, 0.1373],
#           [0.3529, 0.3020, 0.2745,  ..., 0.1647, 0.1608, 0.1529]],
#
#          [[0.4196, 0.4235, 0.4275,  ..., 0.4314, 0.4078, 0.3922],
#           [0.4510, 0.4549, 0.4588,  ..., 0.4431, 0.4196, 0.4039],
#           [0.4784, 0.4824, 0.4863,  ..., 0.4588, 0.4392, 0.4235],
#           ...,
#           [0.3020, 0.2667, 0.2431,  ..., 0.1294, 0.1255, 0.1176],
#           [0.2863, 0.2353, 0.2078,  ..., 0.1098, 0.1020, 0.1059],
#           [0.2980, 0.2471, 0.2196,  ..., 0.1176, 0.1216, 0.1137]]]])

# %%
print("X_train =", X_train.size()[0])
print("y_train =", len(y_train))
print(len(throwaway), "images thrown out")
# Out:
# X_train = 4439
# y_train = 4439
# 61 images thrown out

# %%
from matplotlib import pyplot as plt
import numpy as np

def show_image(img, ax=plt, title=""):
    npimg = img.numpy()
    ax.imshow(np.transpose(npimg, (1, 2, 0)))
    ax.set_title(title)

fig, ax = plt.subplots(9,7, figsize=(25,25))
for i, image in enumerate(throwaway):
    show_image(image[0], ax=ax[i%9, i//9])

# %%
def show_channel(img, ax=plt, title=""):
    npimg = img.numpy()
    ax.imshow(npimg, cmap="gray")
    ax.set_title(title)

def plot_image_channels(img_tensor):
    fig, ax = plt.subplots(2,4, figsize=(10,5))
    show_image(img_tensor, ax[0,0], title="RGB")
    red = img_tensor[0]
    show_channel(red, ax[0, 1], title="Red")
    green = img_tensor[1]
    show_channel(green, ax[0, 2], title="Green")
    blue = img_tensor[2]
    show_channel(blue, ax[0, 3], title="Blue")
    greyscale = (red + green + blue) / 3
    show_channel(greyscale, ax[1,0], title="Greyscale")
    rg_diff = (red - green) / 2 + 0.5
    show_channel(rg_diff, ax[1,1], title="R-G difference")
    rb_diff = (red - blue) / 2 + 0.5
    show_channel(rb_diff, ax[1,2], title="R-B difference")
    gb_diff = (green - blue) / 2 + 0.5
    show_channel(gb_diff, ax[1,3], title="G-B difference")
    fig.tight_layout()

# %%
plot_image_channels(X_train[y_train.index('cherry')+4])

# %%
plot_image_channels(X_train[y_train.index('strawberry')])

# %%
plot_image_channels(X_train[y_train.index('tomato') + 9])

# %%
X_train_proc = torch.zeros((len(train_list), 6, 300, 300))
red = torch.clone(X_train[:, 0, :, :])
green = torch.clone(X_train[:, 1, :, :])
blue = torch.clone(X_train[:, 2, :, :])
X_train_proc[:, 0:3, :, :] = torch.clone(X_train)
X_train_proc[:, 3, :, :] = (red - green) / 2 + 0.5
X_train_proc[:, 4, :, :] = (red - blue) / 2 + 0.5
X_train_proc[:, 5, :, :] = (green - blue) / 2 + 0.5

# %%
def plot_image_channels2(img_tensor):
    fig, ax = plt.subplots(2,4, figsize=(10,5))
    show_image(img_tensor[0:3], ax[0,0], title="RGB")
    red = img_tensor[0]
    show_channel(red, ax[0, 1], title="Red")
    green = img_tensor[1]
    show_channel(green, ax[0, 2], title="Green")
    blue = img_tensor[2]
    show_channel(blue, ax[0, 3], title="Blue")
    greyscale = (red + green + blue) / 3
    show_channel(greyscale, ax[1,0], title="Greyscale")
    rg_diff = img_tensor[3]
    show_channel(rg_diff, ax[1,1], title="R-G difference")
    rb_diff = img_tensor[4]
    show_channel(rb_diff, ax[1,2], title="R-B difference")
    gb_diff = img_tensor[5]
    show_channel(gb_diff, ax[1,3], title="G-B difference")
    fig.tight_layout()

# %%
plot_image_channels2(X_train_proc[y_train.index('cherry') + 8])

# %%
from torch.nn import functional as F

X_train_proc2 = F.interpolate(X_train_proc, size=256)

# %%
plot_image_channels2(X_train_proc2[y_train.index('cherry') + 8])

# %%
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import LabelEncoder

labeller = LabelEncoder().fit(y_train)
dataset = TensorDataset(X_train,
                        torch.tensor(labeller.transform(y_train)))
loader = DataLoader(dataset, batch_size=5, shuffle=True)

# %%
import torch.nn as nn
import torch.optim as optim

criterion = nn.CrossEntropyLoss()

class MLP(nn.Module):
    def __init__(self, channels, size):
        super().__init__()
        self.fc1 = nn.Linear(channels * size * size, 250)
        self.fc2 = nn.Linear(250, 50)
        self.fc3 = nn.Linear(50, 3)

    def forward(self, x):
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

mlp = MLP(3, 300)
mlp_optimizer = optim.SGD(mlp.parameters(), lr=0.001, momentum=0.9)

# %%
history = []
for epoch in range(2):  # loop over the dataset multiple times
    running_loss = 0.0
    for i, data in enumerate(loader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        # zero the parameter gradients
        mlp_optimizer.zero_grad()

        # forward + backward + optimize
        outputs = mlp(inputs)

        loss = criterion(outputs, labels)
        loss.backward()
        mlp_optimizer.step()

        # print statistics
        history.append(loss.item())
        running_loss += loss.item()
        checkin = 100
        if i % checkin == checkin-1:    # print every 200 mini-batches
            print('[%d, %7d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / checkin))
            running_loss = 0.0
# Out:
# [1,     100] loss: 1.134
# [1,     200] loss: 1.089
# [1,     300] loss: 1.104
# [1,     400] loss: 1.098
# [1,     500] loss: 1.074
# [1,     600] loss: 1.090
# [1,     700] loss: 1.069
# [1,     800] loss: 1.084
# [2,     100] loss: 1.051
# [2,     200] loss: 1.078
# [2,     300] loss: 1.076
# [2,     400] loss: 1.046
# [2,     500] loss: 1.052
# [2,     600] loss: 1.049
# [2,     700] loss: 1.070
# [2,     800] loss: 1.072

# %%
def rolling_mean(a, n=10):
    ans = np.cumsum(a)
    ans[n:] = ans[n:] - ans[:-n]
    return ans[n-1:] /n

fig, ax = plt.subplots(1,1)
ax.plot(history)
ax.plot(rolling_mean(history, 50))

# %%
class BaseCNN(nn.Module):
    def __init__(self, channels, size):
        super().__init__()
        kernel_width = 5
        kernel_size = (kernel_width, kernel_width)
        self.conv1 = nn.Conv2d(channels, 24, kernel_size)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(24, 4, kernel_size)
        new_size = int(((size-kernel_width+1)/2-kernel_width+1)/2)
        self.fc1 = nn.Linear(4 * new_size * new_size, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

cnn1 = BaseCNN(3, 300)
cnn1_optimizer = optim.SGD(cnn1.parameters(), lr=0.001, momentum=0.9)

# %%
history1 = []
for epoch in range(2):  # loop over the dataset multiple times
    running_loss = 0.0
    for i, data in enumerate(loader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        # zero the parameter gradients
        cnn1_optimizer.zero_grad()

        # forward + backward + optimize
        outputs = cnn1(inputs)

        loss = criterion(outputs, labels)
        loss.backward()
        cnn1_optimizer.step()

        # print statistics
        history1.append(loss.item())
        running_loss += loss.item()
        checkin = 100
        if i % checkin == checkin-1:    # print every 200 mini-batches
            print('[%d, %7d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / checkin))
            running_loss = 0.0
# Out:
# [1,     100] loss: 1.414
# [1,     200] loss: 1.197
# [1,     300] loss: 1.137
# [1,     400] loss: 1.134
# [1,     500] loss: 1.139
# [1,     600] loss: 1.132
# [1,     700] loss: 1.120
# [1,     800] loss: 1.120
# [2,     100] loss: 1.066
# [2,     200] loss: 1.085
# [2,     300] loss: 1.063
# [2,     400] loss: 1.051
# [2,     500] loss: 1.078
# [2,     600] loss: 1.024
# [2,     700] loss: 1.058
# [2,     800] loss: 1.031

# %%
def rolling_mean(a, n=10):
    ans = np.cumsum(a)
    ans[n:] = ans[n:] - ans[:-n]
    return ans[n-1:] /n

fig, ax = plt.subplots(1,1)
ax.plot(history)
ax.plot(rolling_mean(history, 50))
